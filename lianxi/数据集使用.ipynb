# %%
import os
os.environ['http_proxy'] = 'http://127.0.0.1:7897'
os.environ['https_proxy'] = 'http://127.0.0.1:7897'

# %%
import datasets

data = datasets.load_dataset('madao33/new-title-chinese')
print(data)
data = data['train'].train_test_split(test_size=0.2)
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'content'],
#         num_rows: 5850
#     })
#     validation: Dataset({
#         features: ['title', 'content'],
#         num_rows: 1679
#     })
# })
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'content'],
#         num_rows: 4680
#     })
#     test: Dataset({
#         features: ['title', 'content'],
#         num_rows: 1170
#     })
# })

# %%
data
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'content'],
#         num_rows: 5850
#     })
#     validation: Dataset({
#         features: ['title', 'content'],
#         num_rows: 1679
#     })
# })

# %%
data = datasets.load_dataset('nyu-mll/glue', 'ax')
data
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['premise', 'hypothesis', 'label', 'idx'],
#         num_rows: 1104
#     })
# })

# %%
import datasets

data = datasets.load_dataset('madao33/new-title-chinese', split='train[:50%]')
data[0]
# Out:
# {'title': '望海楼美国打“台湾牌”是危险的赌博',
# ...

# %%
data = datasets.load_dataset('nyu-mll/glue', 'ax')['test']
data

data = data.train_test_split(test_size=0.2, stratify_by_column='label')['train']
data = data.filter(lambda x : 500 >= x['idx'])
data.map()
# Out:
# Filter:   0%|          | 0/883 [00:00<?, ? examples/s]
# Dataset({
#     features: ['premise', 'hypothesis', 'label', 'idx'],
#     num_rows: 392
# })

# %%
# Out:
# 3
